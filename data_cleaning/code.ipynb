# %% [markdown]
# # Data cleaning Case Study- Smartphone
#
# ### Part- 1
# https://colab.research.google.com/drive/1TGYxt3X2YN7SlfocQg_-6A9pakp-WXZX?usp=sharing
#
# ### Part- 2
# https://colab.research.google.com/drive/1TGYxt3X2YN7SlfocQg_-6A9pakp-WXZX?usp=sharing
#
# ### EDA on this Dataset
#
# https://colab.research.google.com/drive/1TGYxt3X2YN7SlfocQg_-6A9pakp-WXZX?usp=sharing

# %% [markdown]
# # Exploratory Data Analysis (Titanic Dataset)
#
# https://colab.research.google.com/drive/13rFqQJqU5RgxSdtUARZAUrzAoweE3rbQ?usp=sharing
