# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# ### Problem-1:
#
# You are given a SQL file link: https://drive.google.com/file/d/1WFt7B84LTHhMueoKmz8W-PRo7xXqmZf3/view?usp=share_link. Read the data by using the file and store it in a excel file. In this data, there are 3 tables named

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="mydb"  # <-- must match SQL dump
)

invoices = pd.read_sql_query('SELECT * FROM invoices', conn)
order_lead = pd.read_sql_query('SELECT * FROM orderleads', conn)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_27492\1158836050.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   invoices = pd.read_sql_query('SELECT * FROM invoices', conn)
# C:\Users\Soham\AppData\Local\Temp\ipykernel_27492\1158836050.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_lead = pd.read_sql_query('SELECT * FROM orderleads', conn)

# %%
with pd.ExcelWriter('supermarket.xlsx') as writer:
    invoices.to_excel(writer,sheet_name="invoices")
    order_lead.to_excel(writer,sheet_name="order_lead")

# %% [markdown]
# ### Problem-2
#
# Go to the site: https://rapidapi.com/wirefreethought/api/geodb-cities. From here, you have to grab the API and have to choose proper routes to get the cities of different countries. After getting the right API, hit that API and create a dataframe of all the cities that you can get by using the API. Then store the dataframe to a SQL. If you need to create an account or have to subscribe, then do that (it has free subscription but has some limitations. Use that free subscription and modify your accordingly to get all the data).

# %% [markdown]
# ## next

# %%
import http.client

conn = http.client.HTTPSConnection("wft-geo-db.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "a1f7b4576amsh5e98594d2a3afa0p137919jsnd8fc22b7d820",
    'x-rapidapi-host': "wft-geo-db.p.rapidapi.com"
}

conn.request("GET", "/v1/geo/places/%7BplaceId%7D/distance?toPlaceId=Q60", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"errors":[{"code":"ENTITY_NOT_FOUND","message":"Place with id '{placeId}' not found"}]}

# %%
### code here
### Rapid API 
import requests

url = "https://wft-geo-db.p.rapidapi.com/v1/geo/adminDivisions"

headers = {
    "X-RapidAPI-Key": "b0f75c828fmsh2b0480a62ab8d23p18178ajsn3267e033ae6a",
    "X-RapidAPI-Host": "wft-geo-db.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

data = response.json()['data']
links = response.json()['links']
metadata = response.json()['metadata']
print(response.text)
# Out:
# {"links":[{"rel":"first","href":"/v1/geo/adminDivisions?offset=0&limit=5"},{"rel":"next","href":"/v1/geo/adminDivisions?offset=5&limit=5"},{"rel":"last","href":"/v1/geo/adminDivisions?offset=155705&limit=5"}],"data":[{"id":3515514,"wikiDataId":"Q4117373","name":"Al Mamzar","country":"United Arab Emirates","countryCode":"AE","region":"Emirate of Dubai","regionCode":"DU","regionWdId":"Q613","latitude":25.309469444,"longitude":55.342811111,"population":0},{"id":3671889,"wikiDataId":"Q1262899","name":"Dubai Internet City","country":"United Arab Emirates","countryCode":"AE","region":"Emirate of Dubai","regionCode":"DU","regionWdId":"Q613","latitude":25.095,"longitude":55.16,"population":24000},{"id":3386644,"wikiDataId":"Q3694483","name":"Ab Band District","country":"Afghanistan","countryCode":"AF","region":"Ghazni Province","regionCode":"GHA","regionWdId":"Q180415","latitude":32.983,"longitude":67.967,"population":0},{"id":3339608,"wikiDataId":"Q2572213","name":"Ab Kamari","country":"Afghanistan","countryCode":"AF","region":"Badghis Province","regionCode":"BDG","regionWdId":"Q172052","latitude":34.925,"longitude":62.901666666,"population":0},{"id":3228129,"wikiDataId":"Q1650529","name":"Achin","country":"Afghanistan","countryCode":"AF","region":"Nangarhar Province","regionCode":"NAN","regionWdId":"Q178471","latitude":34.0894,"longitude":70.683,"population":0}],"metadata":{"currentOffset":0,"totalCount":155706}}

# %%
next_url = links[1]['href']

# %%
count = metadata['totalCount']//5

# %%
import time


for i in range(1,10):
    
    i+= 1
    
    url = "https://wft-geo-db.p.rapidapi.com"
    page = url + next_url
    
    response = requests.request("GET", page, headers=headers)
    
    print(response.json())
    
    links = response.json()['links']
    
    for item in links:
        if item['rel'] == 'next':
            next_url = item['href']
            
    data.extend(response.json()['data'])
    
    time.sleep(2)
# Out:
# {'links': [{'rel': 'first', 'href': '/v1/geo/adminDivisions?offset=0&limit=5'}, {'rel': 'prev', 'href': '/v1/geo/adminDivisions?offset=90&limit=5'}, {'rel': 'next', 'href': '/v1/geo/adminDivisions?offset=100&limit=5'}, {'rel': 'last', 'href': '/v1/geo/adminDivisions?offset=155705&limit=5'}], 'data': [{'id': 3257051, 'wikiDataId': 'Q5434830', 'name': 'Farang Wa Gharu', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Baghlan Province', 'regionCode': 'BGL', 'regionWdId': 'Q170309', 'latitude': 36.136944444, 'longitude': 69.681388888, 'population': 0}, {'id': 3415170, 'wikiDataId': 'Q3918453', 'name': 'Farkhar District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Takhar Province', 'regionCode': 'TAK', 'regionWdId': 'Q186395', 'latitude': 36.47, 'longitude': 69.960833333, 'population': 0}, {'id': 3384461, 'wikiDataId': 'Q2714318', 'name': 'Farsi District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Herat Province', 'regionCode': 'HER', 'regionWdId': 'Q182844', 'latitude': 33.6974, 'longitude': 63.0921, 'population': 0}, {'id': 3211064, 'wikiDataId': 'Q3918456', 'name': 'Farza', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Kabul Province', 'regionCode': 'KAB', 'regionWdId': 'Q188933', 'latitude': 34.793888888, 'longitude': 69.017777777, 'population': 0}, {'id': 3282674, 'wikiDataId': 'Q2887829', 'name': 'Fayzabad District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Badakhshan Province', 'regionCode': 'BDS', 'regionWdId': 'Q165376', 'latitude': 37.05083333, 'longitude': 70.57972222, 'population': 0}], 'metadata': {'currentOffset': 95, 'totalCount': 155706}}
# {'links': [{'rel': 'first', 'href': '/v1/geo/adminDivisions?offset=0&limit=5'}, {'rel': 'prev', 'href': '/v1/geo/adminDivisions?offset=95&limit=5'}, {'rel': 'next', 'href': '/v1/geo/adminDivisions?offset=105&limit=5'}, {'rel': 'last', 'href': '/v1/geo/adminDivisions?offset=155705&limit=5'}], 'data': [{'id': 3295692, 'wikiDataId': 'Q3504927', 'name': 'Fayzabad District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Jowzjan Province', 'regionCode': 'JOW', 'regionWdId': 'Q183036', 'latitude': 36.704444444, 'longitude': 66.329722222, 'population': 0}, {'id': 3434033, 'wikiDataId': 'Q5445211', 'name': 'Feroz Nakhchir', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Samangan Province', 'regionCode': 'SAM', 'regionWdId': 'Q183015', 'latitude': 36.456388888, 'longitude': 67.577222222, 'population': 0}, {'id': 3366856, 'wikiDataId': 'Q3695179', 'name': 'Gardez District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Paktia Province', 'regionCode': 'PIA', 'regionWdId': 'Q182493', 'latitude': 33.60134, 'longitude': 69.24159, 'population': 0}, {'id': 3476099, 'wikiDataId': 'Q794577', 'name': 'Garmsir District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': '
 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Kapisa Province', 'regionCode': 'KAP', 'regionWdId': 'Q173816', 'latitude': 35.073333333, 'longitude': 69.3325, 'population': 0}, {'id': 3362675, 'wikiDataId': 'Q3694366', 'name': 'Hesarak', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Nangarhar Province', 'regionCode': 'NAN', 'regionWdId': 'Q178471', 'latitude': 34.2934, 'longitude': 69.7667, 'population': 0}], 'metadata': {'currentOffset': 125, 'totalCount': 155706}}
# {'links': [{'rel': 'first', 'href': '/v1/geo/adminDivisions?offset=0&limit=5'}, {'rel': 'prev', 'href': '/v1/geo/adminDivisions?offset=125&limit=5'}, {'rel': 'next', 'href': '/v1/geo/adminDivisions?offset=135&limit=5'}, {'rel': 'last', 'href': '/v1/geo/adminDivisions?offset=155705&limit=5'}], 'data': [{'id': 3420645, 'wikiDataId': 'Q1315873', 'name': 'Imam Sahib District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Kunduz Province', 'regionCode': 'KDZ', 'regionWdId': 'Q186418', 'latitude': 37.10841, 'longitude': 68.85371, 'population': 0}, {'id': 3207336, 'wikiDataId': 'Q3694433', 'name': 'Injil District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Herat Province', 'regionCode': 'HER', 'regionWdId': 'Q182844', 'latitude': 34.3001, 'longitude': 62.2499, 'population': 0}, {'id': 3367444, 'wikiDataId': 'Q3309230', 'name': 'Ishkamish District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Takhar Province', 'regionCode': 'TAK', 'regionWdId': 'Q186395', 'latitude': 36.367222222, 'longitude': 69.39, 'population': 0}, {'id': 3374127, 'wikiDataId': 'Q2670884', 'name': 'Ishkashim District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Badakhshan Province', 'regionCode': 'BDS', 'regionWdId': 'Q165376', 'latitude': 36.706388888, 'longitude': 71.573055555, 'population': 0}, {'id': 3383565, 'wikiDataId': 'Q6595513', 'name': 'Ishtarlay District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Daykundi Province', 'regionCode': 'DAY', 'regionWdId': 'Q181220', 'latitude': 34.1, 'longitude': 66.316666666, 'population': 0}], 'metadata': {'currentOffset': 130, 'totalCount': 155706}}
# {'links': [{'rel': 'first', 'href': '/v1/geo/adminDivisions?offset=0&limit=5'}, {'rel': 'prev', 'href': '/v1/geo/adminDivisions?offset=130&limit=5'}, {'rel': 'next', 'href': '/v1/geo/adminDivisions?offset=140&limit=5'}, {'rel': 'last', 'href': '/v1/geo/adminDivisions?offset=155705&limit=5'}], 'data': [{'id': 3291418, 'wikiDataId': 'Q1674831', 'name': 'Istalif', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Kabul Province', 'regionCode': 'KAB', 'regionWdId': 'Q188933', 'latitude': 34.833, 'longitude': 69.077, 'population': 0}, {'id': 3392931, 'wikiDataId': 'Q249194', 'name': 'Jabal Saraj District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Parwan Province', 'regionCode': 'PAR', 'regionWdId': 'Q188157', 'latitude': 35.0657, 'longitude': 69.2639, 'population': 0}, {'id': 3402479, 'wikiDataId': 'Q3696517', 'name': 'Jaghatu', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Maidan Wardak Province', 'regionCode': 'WAR', 'regionWdId': 'Q183056', 'latitude': 33.8554, 'longitude': 68.3951, 'population': 0}, {'id': 3214059, 'wikiDataId': 'Q3694452', 'name': 'Jaghatu District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Ghazni Province', 'regionCode': 'GHA', 'regionWdId': 'Q180415', 'latitude': 33.577222, 'longitude': 68.185556, 'population': 0}, {'id': 3388001, 'wikiDataId': 'Q2724474', 'name': 'Jaghori District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Ghazni Province', 'regionCode': 'GHA', 'regionWdId': 'Q180415', 'latitude': 33.133055555, 'longitude': 67.453611111, 'population': 0}], 'metadata': {'currentOffset': 135, 'totalCount': 155706}}

# %%
cities = pd.DataFrame(data)

# %%
import pymysql

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:@localhost/temp_db")

cities.to_sql("cities",con=engine,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:365, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     364 else:
# --> 365     self.connect()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:681, in Connection.connect(self, sock)
#     680 self._get_server_information()
# --> 681 self._request_authentication()
#     683 # Send "SET NAMES" query on init for:
#     684 # - Ensure charaset (and collation) is set to the server.
#     685 #   - collation_id in handshake packet may be ignored.
#    (...)
#     694 # - https://github.com/wagtail/wagtail/issues/9477
#     695 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:958, in Connection._request_authentication(self)
#     957 self.write_packet(data)
# --> 958 auth_packet = self._read_packet()
#     960 # if authentication method isn't accepted the first byte
#     961 # will have the octet 254
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'temp_db'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[36], line 5
#       1 from sqlalchemy import create_engine
#       3 engine = create_engine("mysql+pymysql://root:@localhost/temp_db")
# ----> 5 cities.to_sql("cities",con=engine,if_exists='append')
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pandas\io\sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2439, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2437 elif should_wrap:
#    2438     assert sqlalchemy_exception is not None
# -> 2439     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2440 else:
#    2441     assert exc_info[1] is not None
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)
#    1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:365, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     363     self._sock = None
#     364 else:
# --> 365     self.connect()
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:681, in Connection.connect(self, sock)
#     678 self._next_seq_id = 0
#     680 self._get_server_information()
# --> 681 self._request_authentication()
#     683 # Send "SET NAMES" query on init for:
#     684 # - Ensure charaset (and collation) is set to the server.
#     685 #   - collation_id in handshake packet may be ignored.
#    (...)
#     694 # - https://github.com/wagtail/wagtail/issues/9477
#     695 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     696 self.set_character_set(self.charset, self.collation)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:958, in Connection._request_authentication(self)
#     955     data += _lenenc_int(len(connect_attrs)) + connect_attrs
#     957 self.write_packet(data)
# --> 958 auth_packet = self._read_packet()
#     960 # if authentication method isn't accepted the first byte
#     961 # will have the octet 254
#     962 if auth_packet.is_auth_switch_request():
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\Soham\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'temp_db'")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Problem 3:
#
# Go to this url: https://www.flipkart.com/search?q=smartphones. This is the url to find phones in flipkart website. You have to extract the below things:
# 1. image url of the phone
# 2. name of the image
# 3. average ratings
# 4. total ratings
# 5. total reviews
# 6. discounted price
# 7. actual price
#
# Extract all the phones which are available in this website. So you have to use the pagination concept. **Also after requesting every page through the url, please wait for a while (minimum 2-3 seconds), otherwise your IP address can be banned to access the flipkart website later.**
#
# After collecting all the data, save that in a JSON file.

# %%
# code here
import requests
from bs4 import BeautifulSoup
import time

import pandas as pd
import numpy as np

# %%
webpage = requests.get('https://www.flipkart.com/search?q=smartphones&page=1').text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
all_divs = soup.find_all('div', class_="tUxRFH")

# %%
len(all_divs)
# Out:
# 0

# %%
phone_image_url = []
phone_name = []
phone_rating = []
phone_num_ratings = []
phone_price = []

for phone in all_divs:
  try:
    phone_image_url.append(phone.find("img",class_="_396cs4")['src'])
  except:
    phone_image_url.append(np.nan)

  try:
    phone_name.append(phone.find("div",class_="_4rR01T").text.strip())
  except:
    phone_name.append(np.nan)

  try:
    phone_rating.append(phone.find("div",class_="_3LWZlK").text.strip())
  except:
    phone_rating.append(np.nan)

  try:
    phone_num_ratings.append(phone.find_all('span',class_='_2_R_DZ')[0].find_all('span')[0].find_all('span')[0].text.strip())
  except:
    phone_num_ratings.append(np.nan)

  try:
    phone_price.append(phone.find("div",class_="_30jeq3 _1_WHN1").text.strip())
  except:
    phone_price.append(np.nan)


df = pd.DataFrame({'phone_name':phone_name,'phone_price':phone_price,'phone_rating':phone_rating,'phone_num_rating':phone_num_ratings,'phone_img_url':phone_image_url})
df
# Out:
# Empty DataFrame
# Columns: [phone_name, phone_price, phone_rating, phone_num_rating, phone_img_url]
# Index: []
